# %%
# Dependencies
import sqlalchemy
from sqlalchemy import create_engine, inspect
from sqlalchemy.ext.declarative import declarative_base
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install pymysql

# %%
#read final combined csv into DF and clean/display
DF = pd.read_csv('/Users/vaishnaviiparamashivam/Documents/Badwords_corr_proj/output/imdb_bword_merged.csv')
#DF = DF.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
DF
# Out:
#      Unnamed: 0                 Movie_Title  Year  Rated     Released  \
# 0             0  10 Things I Hate About You  1999  PG-13  31 Mar 1999
# 1             1                          12  2007  PG-13  20 Sep 2007
# 2             2              12 and Holding  2005      R  07 Jul 2006
# 3             3                  12 Monkeys  1995      R  05 Jan 1996
# 4             4            12 Years a Slave  2013      R  08 Nov 2013
# ..          ...                         ...   ...    ...          ...
# 839         839             This Boy's Life  1993      R  23 Apr 1993
# 840         840                  This Is 40  2012      R  21 Dec 2012
# 841         841                        Thor  2011  PG-13  06 May 2011
# 842         842              Thor: Ragnarok  2017  PG-13  03 Nov 2017
# 843         843                 Three Kings  1999      R  01 Oct 1999
#
#      Runtime                                       Genre             Director  \
# ...

# %%
# Create Engine and Pass in MySQL Connection
engine = create_engine("mysql+pymysql://root:admin223@localhost/moviebadwords")
conn = engine.connect()
#put final csv into mySQL Database
DF.to_sql(con=engine, index_label='id', name="moviebadwords", if_exists='replace')
